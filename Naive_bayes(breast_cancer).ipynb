# %%
print("jai shree Ram")
# Out:
# jai shree Ram

# %% [markdown]
# # Naive Bayes

# %% [raw]
# It is machine learning algorithm which comes under classification supervised machine learning.
# It is mostly use for Realtime classification,Multiclass prediction ,Text classification like (spam and sentiment analysis)
# The features of Naive Bayes algorithm are not fully connected to eachother and this is only Drawback of naive bayes Algorithm

# %%
# let's import the liberary
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# now let's read the data
df=pd.read_csv("breast-cancer.csv")

# %%
# display dataframe
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
# let's perfrom EDA (Explonatry Data Analysis)
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# check null value
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
# let's check duplicate 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# number of row 
df.shape[0]
# Out:
# 569

# %%
# number of columns
df.shape[1]
# Out:
# 32

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %% [raw]
# here the Target is diagonsis and it having object type value. So 1st we have to convert it into integer form.
# So we have two optoion to perform this task.
# 1.Labelencoder
# 2.maping
# here we will use maping

# %%
# So 1st check the unqiure value of the diagnosis
df["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df["diagnosis"]=df["diagnosis"].map({"B":1,"M":0})

# %% [raw]
# Malignant is positive for cancer, as it describes a cancerous tumor that is aggressive, grows rapidly, and can spread to other parts of the body,
# while benign refers to a non-cancerous tumor that typically grows slowly and does not spread

# %%
df["diagnosis"].unique()
# Out:
# array([0, 1])

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                    int64
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
# now every this is ok let's drop the id column becouse it is unnecessory column
df.drop("id",axis=1,inplace=True)

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# let's visualiz the diagnosis data in chart
malignant=df[df["diagnosis"]==0].shape[0]
benign=df[df["diagnosis"]==1].shape[0]
plt.pie([malignant,benign],autopct="%1.1f%%",labels=["Malignant","Benign"])
# Out:
# ([<matplotlib.patches.Wedge at 0x2095073c830>,
# ...
#  [Text(0.4286547905679233, 1.0130424820920245, 'Malignant'),
#   Text(-0.42865446047676137, -1.0130426217654303, 'Benign')],
#  [Text(0.23381170394613998, 0.5525686265956496, '37.3%'),
#   Text(-0.23381152389641527, -0.5525687027811438, '62.7%')])

# %%
df["diagnosis"].value_counts()
# Out:
# diagnosis
# 1    357
# 0    212
# Name: count, dtype: int64

# %% [raw]
# As we can see here our data is inblance .So we need to balance it breafor tain our model

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
# let's create the feature and target
x=df.drop("diagnosis",axis=1)
y=df["diagnosis"]

# %%
# feature (independent data)
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# Target(Dependent data)
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: diagnosis, dtype: int64

# %% [raw]
# As per flow chart 1st let's perform the under_sampling. here we can't perform oversampling becouse this is medical data.As we all know that
# oversampling generate data based on existing but according to me we have to work on fresh data. That's why i chose undersampling

# %%
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler

# %%
# current data 
Counter(y)
# Out:
# Counter({1: 357, 0: 212})

# %%
# create object for the RandomUnderSampler
obj=RandomUnderSampler(sampling_strategy="auto",random_state=40)

# %%
feature,target=obj.fit_resample(x,y)

# %%
# Now check the data
Counter(target)
# Out:
# Counter({0: 212, 1: 212})

# %% [raw]
# Here as you can see this is now become the balanced dataset

# %%
# let's split the data
from sklearn.model_selection import train_test_split

# %%
# Seperate train & test data
x_train,x_test,y_train,y_test=train_test_split(feature,target,test_size=0.1,random_state=20)

# %%
# train data
x_train.head(3)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 229        12.83         22.33           85.26      503.2          0.10880
# 90         14.62         24.02           94.57      662.7          0.08974
# 490        12.25         22.44           78.18      466.5          0.08192
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 229           0.17990         0.16950              0.06861         0.2123
# 90            0.08606         0.03102              0.02957         0.1685
# 490           0.05200         0.01714              0.01261         0.1544
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 229                 0.07254  ...         15.20          30.15
# 90                  0.05866  ...         16.11          29.11
# 490                 0.05976  ...         14.17          31.99
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# ...

# %%
# test data
x_test.head(3)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 311        14.61         15.69           92.68      664.9          0.07618
# 433        18.82         21.97          123.70     1110.0          0.10180
# 13         15.85         23.95          103.70      782.7          0.08401
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 311           0.03515         0.01447              0.01877         0.1632
# 433           0.13890         0.15940              0.08744         0.1943
# 13            0.10020         0.09938              0.05364         0.1847
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 311                 0.05255  ...         16.46          21.75
# 433                 0.06132  ...         22.66          30.93
# 13                  0.05338  ...         16.84          27.66
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# ...

# %%
# let's do model selection 
from sklearn.naive_bayes import GaussianNB

# %%
# create object for the GaussianNB
model=GaussianNB()

# %%
# let's fit the train data
model.fit(feature,target)
# Out:
# GaussianNB()

# %%
# let's perform the train & test predictioin 
train_prediction=model.predict(x_train)
test_prediction=model.predict(x_test)

# %%
# Now it time to evaluate the model
from sklearn.metrics import r2_score,accuracy_score

# %%
# training data accuracy
accuracy_score(y_train,train_prediction)
# Out:
# 0.9396325459317585

# %%
# Testing data accuracy
accuracy_score(y_test,test_prediction)
# Out:
# 0.9534883720930233

# %% [raw]
# Here our model is nomal model.

# %% [markdown]
# ### let's test this model on test data
# #### Here we shall take any random data from test dataset and try to predict and match with real data output and predicted output

# %%
# Here we shall pronounce it patient  1
patient_1=x_test.iloc[0:1,:]
patient_1
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 311        14.61         15.69           92.68      664.9          0.07618
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 311           0.03515         0.01447              0.01877         0.1632
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 311                 0.05255  ...         16.46          21.75
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 311            103.7       840.8            0.1011            0.07087
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 311          0.04746               0.05813           0.253
#
#      fractal_dimension_worst
# 311                  0.05695
#
# [1 rows x 30 columns]

# %%
# check dimention becouse we need 2d data for prediction 
patient_1.ndim
# Out:
# 2

# %% [raw]
# ya it is 2 dimentional

# %%
# let's do prediction 
result=model.predict(patient_1)

# %%
# check answer 
if result==0:
    print("patient_1 is suffering from Malignant Cancer")
else:
    print("patient_1 is safe ")
# Out:
# patient_1 is safe

# %% [markdown]
# ##### Here our model predict Patient_1 is safe it mean's it output is Zero(0)

# %%
# let's check the answer in real dataset of row no. 311
df.iloc[311:312,:]
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 311          1        14.61         15.69           92.68      664.9
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 311          0.07618           0.03515         0.01447              0.01877
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 311         0.1632  ...         16.46          21.75            103.7
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 311       840.8            0.1011            0.07087          0.04746
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 311               0.05813           0.253                  0.05695
#
# [1 rows x 31 columns]

# %% [markdown]
# #### As you can see in row no. 311 of testsing dataset also having Diagnosis value 1 and my model also predict 1 .
